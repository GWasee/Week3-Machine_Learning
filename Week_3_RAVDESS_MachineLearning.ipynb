# %% [markdown]
# <a href="https://colab.research.google.com/github/GWasee/Week3-Machine_Learning/blob/main/Week_3_RAVDESS_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <center><h1> Introduction to Audio Classification with Machine Learning Models </h1></center>
#
#
#
# ### Purpose
# This notebook serves as an introduction to working with audio data for classification problems; it is meant as a learning resource rather than a demonstration of the state-of-the-art. The techniques mentioned in this notebook apply not only to classification problems, but to regression problems and problems dealing with other types of input data as well. I provide an introduction to a few key machine learning models and the logic in choosing their hyperparameters. These objectives are framed by the task of recognizing emotion from snippets of speech audio.
#
#  Training data should be used strictly for training a model, validation data strictly for tuning a model, and test data strictly to evaluate a model once it is tuned - a model should never be tuned to perform better on test data.
#
#
#
#
#
# Classic machine learning models such as Support Vector Machines (SVM), k Nearest Neighbours (kNN), and Random Forests have distinct advantages to deep neural networks in many tasks.

# %% [markdown]
# <!--TABLE OF CONTENTS-->
#
#
# # Table of Contents
#   - [Intro: Speech Emotion Recognition on the RAVDESS dataset](#Intro:-Speech-Emotion-Recognition-on-the-RAVDESS-dataset)
#   - [Machine Learning Process Overview](#Machine-Learning-Process-Overview)
#   - [Feature Extraction](#Feature-Extraction)
#     - [Load the Dataset and Compute Features](#Load-the-Dataset-and-Compute-Features)
#     - [Feature Scaling](#Feature-Scaling)
#   - [Classical Machine Learning Models](#Classical-Machine-Learning-Models)
#     - [Training: The 80/20 Split and Validation](#Training:-The-80/20-Split-and-Validation)
#     - [Comparing Models](#Comparing-Models)
#     - [The Support Vector Machine Classifier](#The-Support-Vector-Machine-Classifier)
#     - [k Nearest Neighbours](#k-Nearest-Neighbours)
#     - [Random Forests](#Random-Forests)

# %% [markdown]
# ## Intro: Speech Emotion Recognition on the RAVDESS dataset
# In this notebook we explore the most common machine learning models, specifically those available off the shelf in scikit-learn.
#
# I'm going to use the RAVDESS dataset (Ryerson Audio-Visual Database of Emotional Speech and Song dataset), created by Steven Livingstone and Frank Russo of Ryerson University. <br>
# [Details of the RAVDESS dataset](https://smartlaboratory.org/ravdess/) <br>
# [Download the dataset used in this notebook](https://zenodo.org/record/1188976) <br> Scroll half-way down the page and find "Audio_Speech_Actors_01-24"<br>
#
# We're going to use the audio-only speech portion of the RAVDESS dataset, ~200MB.
# Audio is sourced from 24 actors (12 male, 12 female) repeating two sentences with
# a variety of emotions and intensity. We get 1440 speech files (24 actors * 60 recordings per actor). Each audio sample has been rated  by a human 10 times for emotional quality.
#
# ## Machine Learning Process Overview
# 1. Feature Engineering: Choose and define the properties which our model will use to evaluate the audio files. <br>
# 2. Feature Extraction: Compute the features for each audio file and build a feature matrix representing all audio files. <br>
# 3. Model exploration: Test candidate models that make sense for the properies of the dataset
# 4. Training the MLP Classifier model: Choose and optimize the properties of our model on validation data - hyperparameters and architechture.  <br>
# 5. Evaluate our model's performance: Evaluate our model's accuracy on validation data and score it against test data which it has never seen in training.<br>
# 6. Explore options for improving our model: Is our dataset the right size? Is our model too complex or too simple? <br>

# %%
#importing the required libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os
# matplotlib complains about the behaviour of librosa.display, so we'll ignore those warnings:
import warnings; warnings.filterwarnings('ignore')

# %% [markdown]
# ## Feature Extraction
# We're going to take full advantage of librosa, a Python library enabling audio analysis and feature extraction.
# Librosa abstracts away all the math and most of the details of mel spectrorgams, chromagrams, and MFCC.
# Although closely related, we're going to take the Mel Spectrogram, MFCC, and chromagrams of each audio file as separate features to try
# and have bit more discriminatory power between samples. <br>
#
# Let's build our feature extraction functions to get a chromagram, a mel spectorgram, and MFC coefficients for each of our audio files. Because the chromagram, mel spectrogram and MFCCs are calculated on audio frames produced by STFT, we're going to get a matrix back from each function, so we'll take the mean of those matrices to produce a single feature array for each feature and each audio sample, i.e. 3 feature arrays per audio sample.
#
# **Chromagram**: Will produce 12 features; One for each of 12 pitch classes
#
# **Mel Spectrogram**: Will produce 128 features; We've defined the number of mel frequency bands at n_mels=128
#
# **MFCC**: Will produce 40 MFCCs; I've set the number of coefficients to return at n_mfcc=40 which I found to work well

# %%
def feature_chromagram(waveform, sample_rate):
    # STFT computed here explicitly; mel spectrogram and MFCC functions do this under the hood
    stft_spectrogram=np.abs(librosa.stft(waveform))
    # Produce the chromagram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    chromagram=np.mean(librosa.feature.chroma_stft(S=stft_spectrogram, sr=sample_rate).T,axis=0)
    return chromagram

def feature_melspectrogram(waveform, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram=np.mean(librosa.feature.melspectrogram(y=waveform, sr=sample_rate, n_mels=128, fmax=8000).T,axis=0)
    return melspectrogram

def feature_mfcc(waveform, sample_rate):
    # Compute the MFCCs for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # 40 filterbanks = 40 coefficients
    mfc_coefficients=np.mean(librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=40).T, axis=0)
    return mfc_coefficients

# %% [markdown]
# We're going to wrap our feature extraction functions so we only have to load each audio file once. After extracting our 3 audio features as NumPy arrays representing a time series, we're going to
# stack them horizontally to create a single feature array.

# %%
def get_features(file):
    # load an individual soundfile
     with soundfile.SoundFile(file) as audio:
        waveform = audio.read(dtype="float32")
        sample_rate = audio.samplerate
        # compute features of soundfile
        chromagram = feature_chromagram(waveform, sample_rate)
        melspectrogram = feature_melspectrogram(waveform, sample_rate)
        mfc_coefficients = feature_mfcc(waveform, sample_rate)

        feature_matrix=np.array([])
        # use np.hstack to stack our feature arrays horizontally to create a feature matrix
        feature_matrix = np.hstack((chromagram, melspectrogram, mfc_coefficients))
        print("Chromagram shape:", chromagram.shape)
        print("Melspectrogram shape:", melspectrogram.shape)
        print("MFCC coefficients shape:", mfc_coefficients.shape)

        return feature_matrix

# %% [markdown]
# ### Load the Dataset and Compute Features
# We have to understand the labelling of the RAVDESS dataset to find the ground truth emotion for each sample.
# Each file is labelled with 7 numbers delimited by a "-".
# Most of the numbers describe metadata about the audio samples such as their format (video and/or audio),
# whether the audio is a song or statement, which of two statements is being read and by which actor.
#
# The third and fourth numbers pertain to the emotional quality of each sample. The third number is in the range of 1-8 with each number representing an emotion.
# The fourth number is either 1 or 2, representing normal (1) or strong (2) emotional intensity.
#
# We're going to define a dictionary based on the third number (emotion) and assign an emotion to each number as specified by the RAVDESS dataset:

# %%
#Emotions in the RAVDESS dataset
emotions ={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

# %% [markdown]
# Finally, let's load our entire dataset and compute the features of each audio file:

# %%
import os, glob

def load_data():
    X,y=[],[]
    count = 0
    for file in glob.glob("/content/drive/MyDrive/IAT481/RAVDESS/Audio_Speech_Actors_01-24/Actor_*/*.wav"):
    # for file in glob.glob("/content/drive/MyDrive/IAT481/Merged_RAVDESS_EMODB/MergedEMODB_RAVDESS/Actor_*/*.wav"):

        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        features = get_features(file)
        X.append(features)
        y.append(emotion)
        count += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{1435} audio samples',end=' ')
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

# %%
a= glob.glob("/content/drive/MyDrive/IAT481/Merged_RAVDESS_EMODB/MergedEMODB_RAVDESS/Actor_*/*.wav")
b= glob.glob("/content/drive/MyDrive/IAT481/RAVDESS/Audio_Speech_Actors_01-24/Actor_*/*.wav")

a[1000]
print(f"Length of list a: {len(a)}")
print(f"Length of list a: {len(b)}")
# Out:
# Length of list a: 1704
# Length of list a: 1435

# %% [markdown]
# Compute the feature matrix and read the emotion labels for the entire dataset.
# Note that our regressor (independent/explanatory variable), usually denoted X, is named 'features', and our regressand (dependent variable), usually denoted y, is named 'emotions'.

# %%
features, emotions = load_data()
# Out:
# Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 2/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 3/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 4/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 5/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 6/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 7/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 8/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 9/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 10/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 11/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 12/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 13/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 14/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 15/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 16/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 17/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 18/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 19/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 20/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 21/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 22/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 23/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 24/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 25/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 26/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 27/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 28/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 29/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 30/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 31/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 32/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 33/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 34/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 35/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 36/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 37/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 38/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 39/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 40/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 41/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 42/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 43/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 44/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 45/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 46/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 47/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 48/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 49/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 50/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 51/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 52/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 53/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 54/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 55/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 56/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 57/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 58/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 59/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 60/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 61/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 62/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 63/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 64/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 65/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 66/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 67/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 68/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 69/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 70/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 71/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 72/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 73/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 74/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 75/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 76/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 77/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 78/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 79/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 80/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 81/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 82/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 83/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 84/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 85/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 86/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 87/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 88/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 89/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 90/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 91/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 92/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 93/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 94/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 95/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 96/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 97/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 98/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 99/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 100/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 101/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 102/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 103/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 104/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 105/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 106/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 107/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 108/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 109/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 110/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 111/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 112/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 113/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 114/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 115/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 116/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 117/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 118/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 119/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 120/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 121/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 122/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 123/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 124/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 125/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 126/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 127/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 128/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 129/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 130/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 131/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 132/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 133/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 134/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 135/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 136/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 137/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 138/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 139/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 140/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 141/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 142/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 143/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 144/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 145/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 146/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 147/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 148/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 149/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 150/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 151/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 152/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 153/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 154/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 155/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 156/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 157/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 158/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 159/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 160/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 161/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 162/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 163/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 164/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 165/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 166/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 167/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 168/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 169/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 170/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 171/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 172/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 173/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 174/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 175/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 176/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 177/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 178/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 179/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 180/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 181/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 182/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 183/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 184/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 185/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 186/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 187/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 188/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 189/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 190/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 191/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 192/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 193/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 194/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 195/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 196/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 197/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 198/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 199/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 200/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 201/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 202/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 203/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 204/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 205/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 206/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 207/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 208/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 209/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 210/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 211/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 212/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 213/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 214/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 215/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 216/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 217/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 218/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 219/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 220/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 221/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 222/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 223/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 224/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 225/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 226/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 227/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 228/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 229/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 230/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 231/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 232/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 233/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 234/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 235/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 236/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 237/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 238/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 239/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 240/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 241/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 242/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 243/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 244/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 245/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 246/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 247/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 248/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 249/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 250/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 251/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 252/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 253/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 254/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 255/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 256/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 257/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 258/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 259/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 260/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 261/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 262/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 263/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 264/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 265/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 266/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 267/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 268/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 269/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 270/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 271/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 272/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 273/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 274/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 275/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 276/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 277/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 278/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 279/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 280/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 281/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 282/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 283/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 284/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 285/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 286/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 287/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 288/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 289/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 290/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 291/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 292/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 293/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 294/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 295/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 296/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 297/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 298/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 299/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 300/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 301/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 302/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 303/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 304/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 305/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 306/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 307/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 308/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 309/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 310/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 311/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 312/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 313/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 314/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 315/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 316/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 317/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 318/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 319/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 320/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 321/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 322/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 323/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 324/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 325/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 326/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 327/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 328/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 329/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 330/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 331/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 332/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 333/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 334/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 335/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 336/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 337/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 338/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 339/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 340/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 341/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 342/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 343/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 344/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 345/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 346/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 347/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 348/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 349/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 350/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 351/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 352/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 353/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 354/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 355/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 356/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 357/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 358/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 359/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 360/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 361/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 362/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 363/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 364/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 365/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 366/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 367/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 368/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 369/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 370/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 371/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 372/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 373/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 374/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 375/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 376/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 377/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 378/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 379/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 380/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 381/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 382/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 383/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 384/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 385/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 386/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 387/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 388/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 389/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 390/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 391/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 392/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 393/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 394/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 395/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 396/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 397/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 398/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 399/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 400/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 401/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 402/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 403/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 404/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 405/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 406/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 407/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# ...
#  Processed 1301/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1302/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1303/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1304/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1305/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1306/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1307/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1308/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1309/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1310/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1311/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1312/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1313/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1314/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1315/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1316/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1317/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1318/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1319/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1320/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1321/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1322/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1323/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1324/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1325/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1326/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1327/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1328/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1329/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1330/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1331/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1332/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1333/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1334/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1335/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1336/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1337/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1338/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1339/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1340/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1341/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1342/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1343/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1344/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1345/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1346/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1347/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1348/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1349/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1350/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1351/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1352/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1353/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1354/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1355/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1356/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1357/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1358/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1359/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1360/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1361/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1362/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1363/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1364/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1365/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1366/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1367/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1368/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1369/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1370/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1371/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1372/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1373/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1374/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1375/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1376/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1377/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1378/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1379/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1380/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1381/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1382/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1383/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1384/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1385/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1386/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1387/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1388/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1389/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1390/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1391/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1392/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1393/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1394/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1395/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1396/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1397/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1398/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1399/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1400/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1401/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1402/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1403/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1404/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1405/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1406/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1407/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1408/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1409/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1410/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1411/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1412/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1413/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1414/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1415/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1416/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1417/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1418/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1419/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1420/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1421/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1422/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1423/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1424/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1425/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1426/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1427/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1428/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1429/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1430/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1431/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1432/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1433/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1434/1435 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1435/1435 audio samples

# %% [markdown]
# Let's see what the features we extracted look like, **also for saving both the features matrix as well as emotions array, we need to convert them to pandas dataframe.**

# %%
print(f'\nAudio samples represented: {features.shape[0]}')
print(f'Numerical features extracted per sample: {features.shape[1]}')
features_df = pd.DataFrame(features) # make it pretty for display


#making dataframe for emotions as well
emotions_df = pd.DataFrame(emotions) # make it pretty for display

features_df
# Out:
# Audio samples represented: 1435
# Numerical features extracted per sample: 180
#            0         1         2         3         4         5         6    \
# 0     0.787751  0.788226  0.798035  0.783412  0.798737  0.822724  0.839857
# 1     0.753914  0.742236  0.772050  0.769192  0.764030  0.780469  0.796326
# 2     0.784023  0.775307  0.780571  0.700013  0.659940  0.672069  0.680253
# 3     0.803011  0.820694  0.794225  0.785298  0.781097  0.775747  0.790438
# 4     0.824843  0.803265  0.766196  0.758505  0.759582  0.764398  0.770296
# ...        ...       ...       ...       ...       ...       ...       ...
# 1430  0.712381  0.718706  0.729118  0.731051  0.762426  0.767861  0.714202
# 1431  0.721674  0.767742  0.792466  0.808218  0.796757  0.779327  0.736381
# 1432  0.706769  0.683181  0.697977  0.724122  0.721807  0.705180  0.688600
# 1433  0.749213  0.768397  0.775770  0.791796  0.819823  0.777179  0.736889
# 1434  0.673069  0.674604  0.694686  0.745122  0.805490  0.782112  0.728258
#
#            7         8         9    ...       170       171       172  \
# 0     0.836526  0.802289  0.776657  ... -0.373787  2.008866 -0.877277
# 1     0.773092  0.767141  0.780961  ... -0.875687 -0.078017 -3.065014
# 2     0.706353  0.741561  0.758811  ...  0.312231 -0.563979 -1.868942
# 3     0.782048  0.762890  0.751916  ... -0.741860  0.141028 -2.078881
# 4     0.775006  0.776775  0.770181  ...  0.504860 -0.482997 -0.632591
# ...        ...       ...       ...  ...       ...       ...       ...
# 1430  0.716141  0.702735  0.674091  ... -2.284616 -1.933366 -3.876371
# 1431  0.693922  0.674518  0.645786  ... -3.148288 -2.260906 -2.762454
# 1432  0.679959  0.683546  0.694773  ... -2.068288  0.622636 -0.366193
# 1433  0.687917  0.662170  0.632087  ... -1.570680 -0.246233 -2.081099
# 1434  0.705044  0.684655  0.673363  ... -2.658766 -2.067885 -4.001461
#
#            173       174       175       176       177       178       179
# 0    -0.857664  1.067517 -0.815837 -0.047750  0.373139 -0.078313 -0.229343
# 1     0.334595 -0.252048 -1.082421 -0.554702 -0.483548 -0.359480 -0.372499
# 2     1.497169  0.264672 -0.511249 -0.284905  0.802863 -0.494821 -1.259620
# 3     0.269869 -0.612658 -1.196501 -0.300618  0.425406  0.101838 -1.202727
# 4     0.493087 -0.781623  0.157664 -0.044414  1.227421  0.229723 -0.525494
# ...        ...       ...       ...       ...       ...       ...       ...
# 1430 -1.835226  0.207644 -0.929847 -1.753684 -1.799933 -1.602293 -1.376285
# 1431 -2.822266 -1.407845 -1.959865 -2.744823 -3.130120 -3.218119 -2.887323
# 1432 -0.103311  2.123292  0.992884  0.305990  0.135866 -0.423351  0.521810
# 1433 -1.482886 -0.458899 -1.514166 -1.748775 -1.746936 -1.913725 -1.715386
# 1434 -2.133724 -0.501628 -2.424063 -2.941581 -3.848197 -2.168639 -2.310325
#
# [1435 rows x 180 columns]

# %% [markdown]
# We have a matrix of dim 1435 x 180. Looks good - 1435 audio samples, one per row, with a series of
# 180 numerical features for each sample.
#
# **Each of the 1435 feature arrays has 180 features composed of 12 chromagram pitch classes + 128 mel spectrogram bands + 40 MFC coefficients.**

# %% [markdown]
# Now we will save our features matrix and emotions array in excel file we dont have to compute them everytime we run the notebook, we can just load them from the excel file whenever required. Make sure to change the path to according to your drive.

# %%
features_df.to_excel('/content/drive/MyDrive/IAT481/Excel/FeaturesRavdess.xlsx')
emotions_df.to_excel('/content/drive/MyDrive/IAT481/Excel/EmotionsRavdess.xlsx')

# %% [markdown]
# ## Load pre-saved Dataset

# %% [markdown]
# Once saved you only need to load them later by running the cell below, and **skip every cell above** except for the one in which we import libraries.

# %% [markdown]
# **Combined Datasets**

# %%
features_df=pd.read_excel('/content/drive/MyDrive/IAT481/Excel/FeaturesRavdess.xlsx',index_col=0)
emotions=pd.read_excel('/content/drive/MyDrive/IAT481/Excel/EmotionsRavdess.xlsx',index_col=0)

# %% [markdown]
# let's see if they have been loaded correctly!

# %%
features_df.head()
emotions.head()
# Out:
#            0
# 0  surprised
# 1    disgust
# 2    disgust
# 3  surprised
# 4  surprised

# %% [markdown]
# Let's see the class balance of our dataset:

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotions, return_counts=True)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels = [emotion for emotion in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()

# Merged dataset has more variety of emotions because of bigger dataset

# %% [markdown]
# **Great, the classes appear to be balanced. That makes the task easier.** All emotions _except_ the neutral class have a "strong" intensity so there are half as many neutral samples. That might have an impact.

# %% [markdown]
# ### Feature Scaling
# To properly train most machine learning models on _most_ datasets, we first need to scale our features. **This is crucial for models which compute distances between data, and especially critical for DNNs**: If there is a difference in the variance of features simply because of their possible range of values, then a model will learn that the features with the greatest variance are the most important. However, **differences in the variance of unscaled features belonging to different and unknown distributions is an inappropriate measure of importance.** Let's check our features' properties:

# %%
# We would usually use df.describe(), but it provides a bit of a mess of information we don't need at the moment.
def print_features(df):
    # Check chromagram feature values
    features_df_chromagram = df.loc[:,:11]
    chroma_min = features_df_chromagram.min().min()
    chroma_max = features_df_chromagram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    chroma_mean = features_df_chromagram.stack().mean()
    chroma_stdev = features_df_chromagram.stack().std()
    print(f'12 Chromagram features:       \
    min = {chroma_min:.3f}, \
    max = {chroma_max:.3f}, \
    mean = {chroma_mean:.3f}, \
    deviation = {chroma_stdev:.3f}')

    # Check mel spectrogram feature values
    features_df_melspectrogram = df.loc[:,12:139]
    mel_min = features_df_melspectrogram.min().min()
    mel_max = features_df_melspectrogram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mel_mean = features_df_melspectrogram.stack().mean()
    mel_stdev = features_df_melspectrogram.stack().std()
    print(f'\n128 Mel Spectrogram features: \
    min = {mel_min:.3f}, \
    max = {mel_max:.3f}, \
    mean = {mel_mean:.3f}, \
    deviation = {mel_stdev:.3f}')

    # Check MFCC feature values
    features_df_mfcc = df.loc[:,140:179]
    mfcc_min = features_df_mfcc.min().min()
    mfcc_max = features_df_mfcc.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mfcc_mean = features_df_mfcc.stack().mean()
    mfcc_stdev = features_df_mfcc.stack().std()
    print(f'\n40 MFCC features:             \
    min = {mfcc_min:.3f},\
    max = {mfcc_max:.3f},\
    mean = {mfcc_mean:.3f},\
    deviation = {mfcc_stdev:.3f}')

print_features(features_df)
# Out:
# 12 Chromagram features:           min = 0.310,     max = 0.874,     mean = 0.666,     deviation = 0.085
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 149.208,     mean = 0.188,     deviation = 1.600
#
# 40 MFCC features:                 min = -873.242,    max = 115.126,    mean = -14.626,    deviation = 98.494

# %% [markdown]
# **There's an obvious imbalance in the variance our features; Our features indeed belong to very different distributions:** our MFC coefficients' deviation is greater than the other features by orders of magnitude. That does not mean MFC coefficients are the most important feature, but rather it is a property of the way they are computed.  We will certainly need to scale this feature set.
#
# We have the choice of sklearn's StandardScaler and MinMaxScaler. Standard scaling subtracts the mean of each feature and divides it by the standard deviation of that feature, producing features with mean at zero and unit variance - that is, a variance and standard deviation of 1. Min-Max scaling transforms each feature to be within a bounded interval that we specify.
#
# In practice, **MinMax scaling is especially useful when we know our features should be in a bounded interval**, such as pixel values in [0,255], while **standard scaling is perhaps more practical for features with unknown distributions** because centering the features at zero-mean with a standard deviation of 1 means extreme values will have less of an impact on the model's learned weights, i.e. the model is less sensitive to outliers.
#
# We'll create MinMax scaled features as well so we can give them a try later on to confirm that standard scaling is better in the absence of knowledge on the appropriate distribution for a dataset's features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = StandardScaler()
# keep our unscaled features just in case we need to process them alternatively
features_scaled = features
features_scaled = scaler.fit_transform(features_scaled)

scaler = MinMaxScaler()
# keep our unscaled features just in case we need to process them alternatively
features_minmax = features
features_minmax = scaler.fit_transform(features_minmax)

# %% [markdown]
# Make sure our features are properly scaled:

# %%
print('\033[1m'+'Standard Scaling:\n'+'\033[0m')
features_scaled_df = pd.DataFrame(features_scaled)
print_features(features_scaled_df)

print('\n\n\033[1m'+'MinMax Scaling:\n'+'\033[0m')
features_minmax_df = pd.DataFrame(features_minmax)
print_features(features_minmax_df)
# Out:
# Standard Scaling:
#
# 12 Chromagram features:           min = -3.957,     max = 2.645,     mean = 0.000,     deviation = 1.000
#
# 128 Mel Spectrogram features:     min = -0.475,     max = 36.480,     mean = 0.000,     deviation = 1.000
#
# 40 MFCC features:                 min = -4.209,    max = 6.240,    mean = 0.000,    deviation = 1.000
#
#
# MinMax Scaling:
#
# 12 Chromagram features:           min = 0.000,     max = 1.000,     mean = 0.611,     deviation = 0.181
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 1.000,     mean = 0.015,     deviation = 0.061
#
# 40 MFCC features:                 min = 0.000,    max = 1.000,    mean = 0.406,    deviation = 0.166

# %% [markdown]
# Perfect. Zero mean and unit variance for standard scaling and in the range [0,1] for MinMax scaling - a default when we don't specify values. We can now move on to building predictive models for these features.

# %% [markdown]
# ## Classical Machine Learning Models
#
#
# Classical machine learning models encompass a broad range of algorithms that have been foundational to the field's development and are still widely used for various predictive tasks. These models can be broadly categorized into supervised and unsupervised learning methods, each suited for different kinds of data and objectives.
#
# We will be looking into few popular Machine Learning Algorithms such as Support Vector Machine(SVM), K-Nearest Neighbors and Random Forest Classifier. There are many other classical models with their own strengths and weaknesses, and the choice of model depends on the specific requirements of the task, including the nature of the data, the complexity of the problem, and the computational efficiency required. Despite the rise of deep learning, classical machine learning models remain vital tools in a data scientist's arsenal due to their efficiency, interpretability, and strong performance in many scenarios.
#
# The use of classic machine learning method is due to the small size of our dataset; Some of the most robust models such as Support vector (machine) classifiers **(SVC) and k-Nearest-Neighbour classifiers (kNN) are particularly suited to smaller datasets and fall apart with huge datasets.**

# %% [markdown]
# ### Training: The 80/20 Split and Validation
# In order to compare models, we'll have to evaluate their performance. The simplest method to do so is to train a model on a portion of our dataset and test it on the remainder. We'll use sklearn's train_test_split to create a standard 80/20 train/test split. The model is fit on 80% of
# the data and tested for performance against 20% of the data, which it has never seen in training - also called the hold-out set.
#  <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/Capture2.PNG?raw=true" width="800">
#
# More accurately, the proper modality for training and scoring a model is to
# 1. Fit/train our model on a _training_ set,
# 2. Evaluate the model on a _validation_ set to tune the hyperparameters for better performance,
# 3. Finally score our model's true performance - its **generalizability** - against a _test_ set, aka the hold-out set.
# 4. Repeat from 2. **Do not tune the model to score well on the test set**.
#
# Different set ratios are used in this approach - a usual example is 60/20/20 train/validation/test.For simplicity, we're going to start with an 80/20 train/test split. The model will be trained on all the training data, and we will check its performance on the test data.
#
#  <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/traintestsplit.PNG?raw=true" width="800">
#
# Define unscaled and scaled training and test sets:

# %%
from sklearn.model_selection import train_test_split


############# Unscaled test/train set #############
X_train, X_test, y_train, y_test =train_test_split(
    features,
    emotions,
    test_size=0.2,
    random_state=69
)

############ Standard Scaled test/train set ###########
# The labels/classes (y_train, y_test) never change, keep old values
X_train_scaled, X_test_scaled, _, _ = train_test_split(
    features_scaled,
    emotions,
    test_size=0.2,
    random_state=69
)

############# MinMax Scaled test/train set ###############
# The labels/classes (y_train, y_test) never change, keep old values
X_train_minmax, X_test_minmax, _, _ = train_test_split(
    features_minmax,
    emotions,
    test_size=0.2,
    random_state=69
)

# %% [markdown]
# ### Comparing Models
# We'll try each off-the-shelf machine learning model from sklearn and pick a few to explore, since these models will train near instantly on this dataset.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

classification_models = [
    KNeighborsClassifier(),#(3),
    SVC(kernel='linear'),#, C=0.025),
    SVC(kernel='rbf'),
    DecisionTreeClassifier(),#max_depth=5),
    RandomForestClassifier(),#max_depth=5, n_estimators=10, max_features=1),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

scores = []
for model in classification_models:
    model.fit(X_train_scaled, y_train)
    score = model.score(X_test_scaled, y_test)
    model_name = type(model).__name__
    if model_name=='SVC' and model.kernel=='rbf': model_name+=' RBF kernel'
    scores.append((model_name,(f'{100*score:.2f}%')))
# Make it pretty
scores_df = pd.DataFrame(scores,columns=['Classifier','Accuracy Score'])
scores_df.sort_values(by='Accuracy Score',axis=0,ascending=False)
# Out:
#                       Classifier Accuracy Score
# 4         RandomForestClassifier         55.40%
# 0           KNeighborsClassifier         54.36%
# 1                            SVC         50.17%
# 2                 SVC RBF kernel         49.13%
# 3         DecisionTreeClassifier         39.02%
# 6                     GaussianNB         26.48%
# 5             AdaBoostClassifier         22.65%
# 7  QuadraticDiscriminantAnalysis         19.16%

# %% [markdown]
# Let's pick the top three - Random Forests, SVC, and kNN - and take a closer look at each of them.

# %% [markdown]
# ### The Support Vector Machine Classifier
#
# We'll go in chronological order. First is the support vector machine classifier (SVC) - a model from the 60s. SVMs are models quick to train for this task and best suited to small datasets due to its quadratic time complexity w.r.t. size of the training dataset (# of training samples). This is also the reason it breaks down with larger datasets since it becomes very expensive to train.
#
# The idea behind SVMs on which the SVC model is based is to find a separating hyperplane - a subspace with dimension one less than that of the feature space - for points in our feature space; i.e. for a 3D space, a hyperplane is a regular plane, in 2D, a line. This idea extends to n dimensions. If points are separable by a hyperplane, they are said to be linearly separable. **Since there are infinite possible separating hyperplanes for any linearly separable feature space, an SVM computes which points are closest to each such hyperplane and uses them to construct a _support vector_. The SVM picks the hyperplane which maximizes the distance - _margin_ - to each support vector.** In this way, we maximize the separating ability of the chosen hyperplane.
#
# The core of SVMs is the kernel. We could map all new points from our input space, where they were not separable by a hyperplane, to a higher dimension in which we have found a hyperplane to separate the points in that space. However, that would be extremely computationally expensive for data that needs to be mapped to much higher dimensions. Instead, we **compute the hyperplane in the higher dimension on our training data and map the hyperplane back to the lower-dimension input space to use for classifying our data. This is the _kernel trick_, whereby the kernel (function) enables us to compute distances to new points in the input space without transforming each to the higher dimensional space - drastically reducing the computational complexity of the SVM.**
#
#  <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/kernel1.png?raw=true" width="800">

# %% [markdown]
# A linear kernel should always be tested because **a linear kernel is much faster to train than a non-linear kernel**; however, properly tuned, a non-linear kernel often provides the best possible predictive performance. **RBF (radial basis function) is a good default to use for a non-linear kernel** and often is the best non-linear kernel because it usually provides a higher accuracy compared to other non-linear kernels at the cost of higher computational complexity. We can afford to try the RBF kernel because our dataset is small.
#
# If you want to explore further please have a look at [this article](https://www.analyticsvidhya.com/blog/2021/10/support-vector-machinessvm-a-complete-guide-for-beginners/)

# %%
from sklearn.svm import SVC

model = SVC(
    C=10,  #higher the value tighter the margin
    gamma='auto',
    kernel='rbf',
    random_state=69
)

model.fit(X_train, y_train)

print(f'SVC Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'SVC Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# SVC Model's accuracy on training set is 100.00%
# SVC Model's accuracy on test set is 54.36%

# %% [markdown]
# Not bad at all for the relatively simple SVC model. **Hyperparameter 𝐶 regulates the margin.** It might do well to optimize the SVC model further if we don't find a better one. As it stands, we are looking for considerably higher performance in this task.
#
# Check out [this link](https://towardsdatascience.com/visualizing-the-effect-of-hyperparameters-on-support-vector-machines-b9eef6f7357b) for visual representation of affect of changes in C and gamma.

# %% [markdown]
# ### k Nearest Neighbours
#
# k Nearest Neighbours (kNN) is next in line, a tried-and-true machine learning method from the 70s. kNN makes a lot of intuitive sense: imagine plotting points on a graph and drawing gates around points that look like they belong to the same group. That's what it is - we **plot our training samples' features and compare a test sample's features' distance to all those points; then just take the _k_ closest points to the test sample and pick the most frequent label/class.** That's it.
#
# kNN is a great starting point for multiclass problems with small datasets, although on large dadtasets less reliable and extremely memory hungry (it stores all training sample points). kNN is also useful in that it makes **no assumptions about the underlying distribution of the data set - so kNNs work well for both linear and non-linear data.** In the 2D example:
#
# <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/knn.png?raw=true" width=400 height=400 />

# %%
from sklearn.neighbors import KNeighborsClassifier

####### Default kNN  ########
model = KNeighborsClassifier(
)

model.fit(X_train, y_train)

print(f'Default kNN Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Default kNN Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%\n')

##### (hastily) tuned kNN ######
model = KNeighborsClassifier(
    n_neighbors = 5,
    weights = 'distance',
    algorithm = 'brute',
    n_jobs=4
)

model.fit(X_train, y_train)

print(f'kNN Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'kNN Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# Default kNN Model's accuracy on training set is 66.55%
# Default kNN Model's accuracy on test set is 40.07%
#
# kNN Model's accuracy on training set is 100.00%
# kNN Model's accuracy on test set is 43.90%

# %% [markdown]
# **The brute-force algorithm computes distances between all pairs of points in the training set; works especially well for small datasets** but wildly inefficient w.r.t. increasing samples and feature space dimension. Not bad for 2 minutes of work, but still not suitable for this task.

# %% [markdown]
# ### Random Forests
# Finally, and before resorting to deep learning methods, let's try a Random Forest -  a model from the 21st century (2001). **We train many distinct decision trees which are essentially directed acyclic graphs (DAGs), somewhat similar to a flow chart. The collection of (decision) trees makes up our Random Forest.**
#
# At each node of the tree we have a function (a rule) that evaluates whether the features of samples input to that node belong to one class or another. Each branch of the tree (or, edge of the graph) defines one of two possible results from a node, and each leaf is one of two decisions made by its parent node. **Each tree in the forest evaluates a random subset of the training samples' features and has a rule at each level of the tree that classifies based on these random features - hence, _Random_ Forest. This random selection of features makes Random Forests robust to outliers**, as such features will have less of an impact in the scope of the entire forest, most of whose trees operate on the "real" features.
#
# **Random Forests are excellent models to use as a benchmark due to their low time complexity to train and because it is an ensemble method, their robustness to unknown distributions and outliers in the dataset,** meaning Random Forests require relatively little exploratory analysis in both the data and training the model to get an idea of their performance in a task.
#
# <img src="https://github.com/IliaZenkov/sklearn-audio-classification/blob/master/img/randomforest.png?raw=true" width=500 height=500 />

# %%
from sklearn.ensemble import RandomForestClassifier

####### Default Random Forest ########
model = RandomForestClassifier(
    random_state=69
)

model.fit(X_train, y_train)

print(f'Default Random Forest Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Default Random Forest Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%\n')


########## Tuned Random Forest #######
model = RandomForestClassifier(
    n_estimators = 500,
    criterion ='entropy',
    warm_start = True,
    max_features = 'sqrt',
    oob_score = True, # more on this below
    random_state=69
)

model.fit(X_train, y_train)

print(f'Random Forest Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Random Forest Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# Default Random Forest Model's accuracy on training set is 100.00%
# Default Random Forest Model's accuracy on test set is 52.61%
#
# Random Forest Model's accuracy on training set is 100.00%
# Random Forest Model's accuracy on test set is 54.01%

# %% [markdown]
# Not bad for zero effort put into the default model. **Random Forests make a good benchmark model**, especially when strapped for time.
#
# **_Max features_ defines size of random feature subset decided upon at each node; sqrt(#features) is a good default for classification.**
#
# **_Gini_ and _Entropy_ are functions computing quality of classified samples within each node; they almost always provide similar performance but Entropy is more suited to classification while Gini is better for continuous variables.**

# %% [markdown]
# As wonderful as Random Forests are, it's clear that we're going to need to pull out bigger guns if we want to get appreciable performance on this dataset, perhaps even with good generalizability on test data. DNNs(Deep Neural Networks) are the next step-up in complexity from classical machine learning models, and we will start at the first rung on that ladder:Simple Perceptron in next lab!
