# %% [markdown]
# <a href="https://colab.research.google.com/github/GWasee/Week3-Machine_Learning/blob/branch1/Week_3_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <center><h1> Introduction to Audio Classification with Machine Learning Models </h1></center>
#
#
#
# ### Purpose
# This notebook serves as an introduction to working with audio data for classification problems; it is meant as a learning resource rather than a demonstration of the state-of-the-art. The techniques mentioned in this notebook apply not only to classification problems, but to regression problems and problems dealing with other types of input data as well. I provide an introduction to a few key machine learning models and the logic in choosing their hyperparameters. These objectives are framed by the task of recognizing emotion from snippets of speech audio.
#
#  Training data should be used strictly for training a model, validation data strictly for tuning a model, and test data strictly to evaluate a model once it is tuned - a model should never be tuned to perform better on test data.
#
#
#
#
#
# Classic machine learning models such as Support Vector Machines (SVM), k Nearest Neighbours (kNN), and Random Forests have distinct advantages to deep neural networks in many tasks.

# %% [markdown]
# <!--TABLE OF CONTENTS-->
#
#
# # Table of Contents
#   - [Intro: Speech Emotion Recognition on the RAVDESS dataset](#Intro:-Speech-Emotion-Recognition-on-the-RAVDESS-dataset)
#   - [Machine Learning Process Overview](#Machine-Learning-Process-Overview)
#   - [Feature Extraction](#Feature-Extraction)
#     - [Load the Dataset and Compute Features](#Load-the-Dataset-and-Compute-Features)
#     - [Feature Scaling](#Feature-Scaling)
#   - [Classical Machine Learning Models](#Classical-Machine-Learning-Models)
#     - [Training: The 80/20 Split and Validation](#Training:-The-80/20-Split-and-Validation)
#     - [Comparing Models](#Comparing-Models)
#     - [The Support Vector Machine Classifier](#The-Support-Vector-Machine-Classifier)
#     - [k Nearest Neighbours](#k-Nearest-Neighbours)
#     - [Random Forests](#Random-Forests)

# %% [markdown]
# ## Intro: Speech Emotion Recognition on the RAVDESS dataset
# In this notebook we explore the most common machine learning models, specifically those available off the shelf in scikit-learn.
#
# I'm going to use the RAVDESS dataset (Ryerson Audio-Visual Database of Emotional Speech and Song dataset), created by Steven Livingstone and Frank Russo of Ryerson University. <br>
# [Details of the RAVDESS dataset](https://smartlaboratory.org/ravdess/) <br>
# [Download the dataset used in this notebook](https://zenodo.org/record/1188976) <br> Scroll half-way down the page and find "Audio_Speech_Actors_01-24"<br>
#
# We're going to use the audio-only speech portion of the RAVDESS dataset, ~200MB.
# Audio is sourced from 24 actors (12 male, 12 female) repeating two sentences with
# a variety of emotions and intensity. We get 1440 speech files (24 actors * 60 recordings per actor). Each audio sample has been rated  by a human 10 times for emotional quality.
#
# ## Machine Learning Process Overview
# 1. Feature Engineering: Choose and define the properties which our model will use to evaluate the audio files. <br>
# 2. Feature Extraction: Compute the features for each audio file and build a feature matrix representing all audio files. <br>
# 3. Model exploration: Test candidate models that make sense for the properies of the dataset
# 4. Training the MLP Classifier model: Choose and optimize the properties of our model on validation data - hyperparameters and architechture.  <br>
# 5. Evaluate our model's performance: Evaluate our model's accuracy on validation data and score it against test data which it has never seen in training.<br>
# 6. Explore options for improving our model: Is our dataset the right size? Is our model too complex or too simple? <br>

# %%
#importing the required libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os
# matplotlib complains about the behaviour of librosa.display, so we'll ignore those warnings:
import warnings; warnings.filterwarnings('ignore')

# %% [markdown]
# ## Feature Extraction
# We're going to take full advantage of librosa, a Python library enabling audio analysis and feature extraction.
# Librosa abstracts away all the math and most of the details of mel spectrorgams, chromagrams, and MFCC.
# Although closely related, we're going to take the Mel Spectrogram, MFCC, and chromagrams of each audio file as separate features to try
# and have bit more discriminatory power between samples. <br>
#
# Let's build our feature extraction functions to get a chromagram, a mel spectorgram, and MFC coefficients for each of our audio files. Because the chromagram, mel spectrogram and MFCCs are calculated on audio frames produced by STFT, we're going to get a matrix back from each function, so we'll take the mean of those matrices to produce a single feature array for each feature and each audio sample, i.e. 3 feature arrays per audio sample.
#
# **Chromagram**: Will produce 12 features; One for each of 12 pitch classes
#
# **Mel Spectrogram**: Will produce 128 features; We've defined the number of mel frequency bands at n_mels=128
#
# **MFCC**: Will produce 40 MFCCs; I've set the number of coefficients to return at n_mfcc=40 which I found to work well

# %%
def feature_chromagram(waveform, sample_rate):
    # STFT computed here explicitly; mel spectrogram and MFCC functions do this under the hood
    stft_spectrogram=np.abs(librosa.stft(waveform))
    # Produce the chromagram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    chromagram=np.mean(librosa.feature.chroma_stft(S=stft_spectrogram, sr=sample_rate).T,axis=0)
    return chromagram

def feature_melspectrogram(waveform, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram=np.mean(librosa.feature.melspectrogram(y=waveform, sr=sample_rate, n_mels=128, fmax=8000).T,axis=0)
    return melspectrogram

def feature_mfcc(waveform, sample_rate):
    # Compute the MFCCs for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # 40 filterbanks = 40 coefficients
    mfc_coefficients=np.mean(librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=40).T, axis=0)
    return mfc_coefficients

# %% [markdown]
# We're going to wrap our feature extraction functions so we only have to load each audio file once. After extracting our 3 audio features as NumPy arrays representing a time series, we're going to
# stack them horizontally to create a single feature array.

# %%
def get_features(file):
    # load an individual soundfile
     with soundfile.SoundFile(file) as audio:
        waveform = audio.read(dtype="float32")
        sample_rate = audio.samplerate
        # compute features of soundfile
        chromagram = feature_chromagram(waveform, sample_rate)
        melspectrogram = feature_melspectrogram(waveform, sample_rate)
        mfc_coefficients = feature_mfcc(waveform, sample_rate)

        feature_matrix=np.array([])
        # use np.hstack to stack our feature arrays horizontally to create a feature matrix
        feature_matrix = np.hstack((chromagram, melspectrogram, mfc_coefficients))
        print("Chromagram shape:", chromagram.shape)
        print("Melspectrogram shape:", melspectrogram.shape)
        print("MFCC coefficients shape:", mfc_coefficients.shape)

        return feature_matrix

# %% [markdown]
# ### Load the Dataset and Compute Features
# We have to understand the labelling of the RAVDESS dataset to find the ground truth emotion for each sample.
# Each file is labelled with 7 numbers delimited by a "-".
# Most of the numbers describe metadata about the audio samples such as their format (video and/or audio),
# whether the audio is a song or statement, which of two statements is being read and by which actor.
#
# The third and fourth numbers pertain to the emotional quality of each sample. The third number is in the range of 1-8 with each number representing an emotion.
# The fourth number is either 1 or 2, representing normal (1) or strong (2) emotional intensity.
#
# We're going to define a dictionary based on the third number (emotion) and assign an emotion to each number as specified by the RAVDESS dataset:

# %%
#Emotions in the RAVDESS dataset
emotions ={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

# %% [markdown]
# Finally, let's load our entire dataset and compute the features of each audio file:

# %%
import os, glob

def load_data():
    X,y=[],[]
    count = 0
    # for file in glob.glob("/content/drive/MyDrive/IAT481/RAVDESS/Audio_Speech_Actors_01-24/Actor_*/*.wav"):
    for file in glob.glob("/content/drive/MyDrive/IAT481/Merged_RAVDESS_EMODB/MergedEMODB_RAVDESS/Actor_*/*.wav"):

        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        features = get_features(file)
        X.append(features)
        y.append(emotion)
        count += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{1704} audio samples',end=' ')
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

# %%
a= glob.glob("/content/drive/MyDrive/IAT481/Merged_RAVDESS_EMODB/MergedEMODB_RAVDESS/Actor_*/*.wav")

a[1000]
print(f"Length of list a: {len(a)}")
# Out:
# Length of list a: 1704

# %%
# x=0
# for file_nam in glob.glob("/content/drive/MyDrive/IAT481/Merged_RAVDESS_EMODB/MergedEMODB_RAVDESS/Actor_*/*.wav"):
#   print(x,emotions[file_nam.split("-")[2]])
# #   print(x,get_features(file_nam))


# features2, emotions = load_data2()

# import os, glob


# def load_data2():
#     X2,y2=[],[]
#     count2 = 0
#     for file2 in glob.glob("/content/drive/MyDrive/IAT481/EMODB/renamed_EMODB/Actor_*/*.wav"):
#         file_name2=os.path.basename(file2)
#         emotion2=emotions[file_name2.split("-")[2]]
#         features2 = get_features(file2)
#         X2.append(features2)
#         y2.append(emotion2)
#         count2 += 1
#         # '\r' + end='' results in printing over same line
#         print('\r' + f' Processed {count2}/{600} audio samples',end=' ')
#     # Return arrays to plug into sklearn's cross-validation algorithms
#     return np.array(X2), np.array(y2)

# %% [markdown]
# Compute the feature matrix and read the emotion labels for the entire dataset.
# Note that our regressor (independent/explanatory variable), usually denoted X, is named 'features', and our regressand (dependent variable), usually denoted y, is named 'emotions'.

# %%
features, emotions = load_data()
# Out:
# Streaming output truncated to the last 5000 lines.
#  Processed 38/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 39/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 40/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 41/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 42/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 43/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 44/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 45/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 46/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 47/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 48/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 49/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 50/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 51/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 52/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 53/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 54/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 55/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 56/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 57/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 58/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 59/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 60/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 61/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 62/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 63/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 64/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 65/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 66/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 67/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 68/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 69/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 70/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 71/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 72/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 73/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 74/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 75/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 76/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 77/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 78/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 79/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 80/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 81/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 82/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 83/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 84/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 85/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 86/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 87/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 88/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 89/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 90/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 91/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 92/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 93/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 94/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 95/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 96/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 97/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 98/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 99/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 100/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 101/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 102/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 103/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 104/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 105/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 106/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 107/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 108/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 109/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 110/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 111/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 112/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 113/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 114/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 115/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 116/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 117/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 118/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 119/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 120/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 121/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 122/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 123/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 124/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 125/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 126/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 127/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 128/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 129/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 130/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 131/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 132/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 133/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 134/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 135/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 136/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 137/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 138/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 139/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 140/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 141/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 142/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 143/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 144/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 145/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 146/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 147/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 148/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 149/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 150/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 151/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 152/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 153/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 154/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 155/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 156/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 157/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 158/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 159/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 160/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 161/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 162/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 163/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 164/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 165/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 166/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 167/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 168/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 169/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 170/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 171/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 172/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 173/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 174/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 175/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 176/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 177/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 178/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 179/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 180/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 181/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 182/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 183/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 184/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 185/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 186/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 187/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 188/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 189/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 190/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 191/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 192/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 193/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 194/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 195/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 196/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 197/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 198/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 199/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 200/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 201/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 202/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 203/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 204/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 205/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 206/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 207/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 208/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 209/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 210/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 211/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 212/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 213/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 214/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 215/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 216/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 217/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 218/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 219/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 220/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 221/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 222/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 223/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 224/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 225/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 226/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 227/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 228/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 229/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 230/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 231/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 232/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 233/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 234/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 235/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 236/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 237/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 238/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 239/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 240/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 241/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 242/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 243/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 244/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 245/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 246/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 247/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 248/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 249/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 250/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 251/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 252/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 253/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 254/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 255/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 256/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 257/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 258/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 259/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 260/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 261/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 262/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 263/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 264/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 265/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 266/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 267/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 268/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 269/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 270/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 271/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 272/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 273/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 274/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 275/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 276/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 277/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 278/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 279/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 280/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 281/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 282/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 283/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 284/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 285/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 286/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 287/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 288/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 289/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 290/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 291/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 292/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 293/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 294/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 295/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 296/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 297/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 298/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 299/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 300/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 301/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 302/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 303/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 304/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 305/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 306/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 307/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 308/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 309/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 310/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 311/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 312/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 313/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 314/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 315/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 316/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 317/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 318/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 319/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 320/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 321/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 322/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 323/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 324/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 325/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 326/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 327/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 328/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 329/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 330/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 331/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 332/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 333/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 334/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 335/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 336/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 337/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 338/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 339/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 340/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 341/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 342/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 343/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 344/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 345/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 346/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 347/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 348/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 349/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 350/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 351/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 352/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 353/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 354/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 355/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 356/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 357/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 358/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 359/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 360/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 361/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 362/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 363/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 364/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 365/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 366/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 367/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 368/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 369/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 370/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 371/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 372/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 373/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 374/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 375/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 376/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 377/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 378/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 379/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 380/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 381/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 382/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 383/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 384/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 385/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 386/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 387/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 388/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 389/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 390/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 391/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 392/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 393/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 394/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 395/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 396/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 397/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 398/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 399/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 400/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 401/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 402/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 403/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 404/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 405/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 406/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 407/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 408/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 409/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 410/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 411/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 412/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 413/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 414/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 415/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 416/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 417/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 418/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 419/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 420/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 421/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 422/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 423/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 424/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 425/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 426/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 427/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 428/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 429/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 430/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 431/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 432/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 433/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 434/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 435/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 436/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 437/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 438/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 439/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 440/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 441/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 442/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 443/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 444/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# ...
#  Processed 1570/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1571/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1572/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1573/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1574/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1575/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1576/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1577/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1578/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1579/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1580/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1581/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1582/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1583/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1584/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1585/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1586/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1587/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1588/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1589/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1590/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1591/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1592/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1593/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1594/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1595/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1596/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1597/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1598/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1599/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1600/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1601/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1602/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1603/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1604/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1605/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1606/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1607/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1608/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1609/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1610/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1611/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1612/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1613/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1614/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1615/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1616/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1617/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1618/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1619/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1620/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1621/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1622/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1623/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1624/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1625/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1626/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1627/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1628/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1629/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1630/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1631/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1632/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1633/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1634/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1635/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1636/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1637/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1638/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1639/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1640/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1641/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1642/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1643/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1644/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1645/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1646/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1647/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1648/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1649/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1650/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1651/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1652/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1653/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1654/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1655/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1656/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1657/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1658/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1659/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1660/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1661/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1662/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1663/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1664/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1665/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1666/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1667/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1668/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1669/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1670/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1671/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1672/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1673/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1674/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1675/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1676/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1677/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1678/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1679/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1680/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1681/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1682/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1683/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1684/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1685/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1686/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1687/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1688/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1689/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1690/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1691/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1692/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1693/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1694/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1695/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1696/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1697/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1698/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1699/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1700/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1701/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1702/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1703/1704 audio samples Chromagram shape: (12,)
# Melspectrogram shape: (128,)
# MFCC coefficients shape: (40,)
#  Processed 1704/1704 audio samples

# %% [markdown]
# Let's see what the features we extracted look like, **also for saving both the features matrix as well as emotions array, we need to convert them to pandas dataframe.**

# %%
print(f'\nAudio samples represented: {features.shape[0]}')
print(f'Numerical features extracted per sample: {features.shape[1]}')
features_df = pd.DataFrame(features) # make it pretty for display


#making dataframe for emotions as well
emotions_df = pd.DataFrame(emotions) # make it pretty for display

features_df

# print(f'\nAudio samples represented: {features2.shape[0]}')
# print(f'Numerical features extracted per sample: {features2.shape[1]}')
# features2_df = pd.DataFrame(features2) # make it pretty for display


# #making dataframe for emotions as well
# emotions2_df = pd.DataFrame(emotions2) # make it pretty for display

# features2_df
# Out:
# Audio samples represented: 1704
# Numerical features extracted per sample: 180
#            0         1         2         3         4         5         6    \
# 0     0.623977  0.626034  0.631625  0.674646  0.746090  0.765786  0.707922
# 1     0.637039  0.629132  0.637233  0.662633  0.695195  0.710128  0.725462
# 2     0.631117  0.606934  0.641947  0.625884  0.642375  0.673202  0.710412
# 3     0.576098  0.580652  0.617902  0.668807  0.682711  0.706620  0.710662
# 4     0.628088  0.649669  0.637619  0.639352  0.711655  0.740116  0.730665
# ...        ...       ...       ...       ...       ...       ...       ...
# 1699  0.465189  0.462528  0.449644  0.460654  0.476605  0.492283  0.516932
# 1700  0.632722  0.600716  0.614806  0.630751  0.630522  0.651543  0.684345
# 1701  0.631892  0.630022  0.627687  0.616110  0.600657  0.597530  0.618320
# 1702  0.460273  0.428281  0.450717  0.452955  0.477504  0.486522  0.506679
# 1703  0.612675  0.576026  0.553289  0.536383  0.542740  0.594069  0.621286
#
#            7         8         9    ...       170       171       172  \
# 0     0.706870  0.740906  0.741521  ... -3.286624 -1.500852 -1.983862
# 1     0.756882  0.755365  0.706795  ... -2.569088 -0.683576 -2.387725
# 2     0.738465  0.771874  0.731565  ... -3.133229 -2.845857 -3.100154
# 3     0.735204  0.765713  0.714530  ... -3.408489 -2.397723 -2.586820
# 4     0.697500  0.682969  0.628888  ...  0.814820  4.026620  1.634076
# ...        ...       ...       ...  ...       ...       ...       ...
# 1699  0.541659  0.566635  0.542518  ... -1.553281 -3.932138 -1.924470
# 1700  0.706835  0.696102  0.654440  ... -0.482988 -0.684488  1.060388
# 1701  0.623001  0.654439  0.622531  ...  0.500897  1.291017 -0.041403
# 1702  0.564598  0.548166  0.509646  ... -0.183203 -0.462983 -0.115680
# 1703  0.643214  0.729858  0.729243  ... -4.689472 -2.005129 -1.024544
#
#            173       174       175       176       177       178       179
# 0     3.316448  1.229970  4.081339  5.464694  4.349416  2.392397  0.002948
# 1    -0.005834 -1.990430 -0.650840  1.014657  0.915418  1.069058  1.553290
# 2    -1.261223 -2.012758 -0.422779 -0.148605  0.627146 -0.035839  0.448084
# 3    -0.248526 -1.842495  1.902710  1.352805  1.790393  2.591391  0.459907
# 4     1.333650 -2.119497 -0.659883  0.542175 -0.216996 -0.196227  0.505378
# ...        ...       ...       ...       ...       ...       ...       ...
# 1699 -2.874562 -2.029576  0.234562  1.221652  1.779323  2.259865  3.431705
# 1700  1.086750  1.422616  0.783379 -0.297070 -0.633813 -0.117706  1.660300
# 1701  0.612038  1.309492  0.024908 -0.319914  1.399153 -0.071439  2.555313
# 1702  0.166845  2.417052 -0.115605 -0.857513 -0.481412  0.316559  2.266915
# 1703 -1.683853  2.919479  2.462628  3.766777  4.480668  4.624168  4.204729
#
# [1704 rows x 180 columns]

# %% [markdown]
# We have a matrix of dim 1435 x 180. Looks good - 1435 audio samples, one per row, with a series of
# 180 numerical features for each sample.
#
# **Each of the 1435 feature arrays has 180 features composed of 12 chromagram pitch classes + 128 mel spectrogram bands + 40 MFC coefficients.**

# %% [markdown]
# Now we will save our features matrix and emotions array in excel file we dont have to compute them everytime we run the notebook, we can just load them from the excel file whenever required. Make sure to change the path to according to your drive.

# %%
features_df.to_excel('/content/drive/MyDrive/IAT481/Excel/featuresMergedRavdess.xlsx')
emotions_df.to_excel('/content/drive/MyDrive/IAT481/Excel/emotionsMergedRavdess.xlsx')

# %% [markdown]
# ## Load pre-saved Dataset

# %% [markdown]
# Once saved you only need to load them later by running the cell below, and **skip every cell above** except for the one in which we import libraries.

# %%
features_df=pd.read_excel('/content/drive/MyDrive/IAT481/Excel/featuresMergedRavdess.xlsx',index_col=0)
emotions=pd.read_excel('/content/drive/MyDrive/IAT481/Excel/emotionsMergedRavdess.xlsx',index_col=0)

# %% [markdown]
# let's see if they have been loaded correctly!

# %%
features.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-1fb734ea9054> in <cell line: 1>()
# ----> 1 features()
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# Let's see the class balance of our dataset:

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotions, return_counts=True)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels = [emotion for emotion in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()

# %% [markdown]
# **Great, the classes appear to be balanced. That makes the task easier.** All emotions _except_ the neutral class have a "strong" intensity so there are half as many neutral samples. That might have an impact.

# %% [markdown]
# ### Feature Scaling
# To properly train most machine learning models on _most_ datasets, we first need to scale our features. **This is crucial for models which compute distances between data, and especially critical for DNNs**: If there is a difference in the variance of features simply because of their possible range of values, then a model will learn that the features with the greatest variance are the most important. However, **differences in the variance of unscaled features belonging to different and unknown distributions is an inappropriate measure of importance.** Let's check our features' properties:

# %%
# We would usually use df.describe(), but it provides a bit of a mess of information we don't need at the moment.
def print_features(df):
    # Check chromagram feature values
    features_df_chromagram = df.loc[:,:11]
    chroma_min = features_df_chromagram.min().min()
    chroma_max = features_df_chromagram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    chroma_mean = features_df_chromagram.stack().mean()
    chroma_stdev = features_df_chromagram.stack().std()
    print(f'12 Chromagram features:       \
    min = {chroma_min:.3f}, \
    max = {chroma_max:.3f}, \
    mean = {chroma_mean:.3f}, \
    deviation = {chroma_stdev:.3f}')

    # Check mel spectrogram feature values
    features_df_melspectrogram = df.loc[:,12:139]
    mel_min = features_df_melspectrogram.min().min()
    mel_max = features_df_melspectrogram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mel_mean = features_df_melspectrogram.stack().mean()
    mel_stdev = features_df_melspectrogram.stack().std()
    print(f'\n128 Mel Spectrogram features: \
    min = {mel_min:.3f}, \
    max = {mel_max:.3f}, \
    mean = {mel_mean:.3f}, \
    deviation = {mel_stdev:.3f}')

    # Check MFCC feature values
    features_df_mfcc = df.loc[:,140:179]
    mfcc_min = features_df_mfcc.min().min()
    mfcc_max = features_df_mfcc.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mfcc_mean = features_df_mfcc.stack().mean()
    mfcc_stdev = features_df_mfcc.stack().std()
    print(f'\n40 MFCC features:             \
    min = {mfcc_min:.3f},\
    max = {mfcc_max:.3f},\
    mean = {mfcc_mean:.3f},\
    deviation = {mfcc_stdev:.3f}')

print_features(features_df)
# Out:
# 12 Chromagram features:           min = 0.276,     max = 0.888,     mean = 0.653,     deviation = 0.092
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 872.107,     mean = 0.787,     deviation = 7.578
#
# 40 MFCC features:                 min = -873.242,    max = 121.174,    mean = -12.894,    deviation = 91.540

# %% [markdown]
# **There's an obvious imbalance in the variance our features; Our features indeed belong to very different distributions:** our MFC coefficients' deviation is greater than the other features by orders of magnitude. That does not mean MFC coefficients are the most important feature, but rather it is a property of the way they are computed.  We will certainly need to scale this feature set.
#
# We have the choice of sklearn's StandardScaler and MinMaxScaler. Standard scaling subtracts the mean of each feature and divides it by the standard deviation of that feature, producing features with mean at zero and unit variance - that is, a variance and standard deviation of 1. Min-Max scaling transforms each feature to be within a bounded interval that we specify.
#
# In practice, **MinMax scaling is especially useful when we know our features should be in a bounded interval**, such as pixel values in [0,255], while **standard scaling is perhaps more practical for features with unknown distributions** because centering the features at zero-mean with a standard deviation of 1 means extreme values will have less of an impact on the model's learned weights, i.e. the model is less sensitive to outliers.
#
# We'll create MinMax scaled features as well so we can give them a try later on to confirm that standard scaling is better in the absence of knowledge on the appropriate distribution for a dataset's features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = StandardScaler()
# keep our unscaled features just in case we need to process them alternatively
features_scaled = features
features_scaled = scaler.fit_transform(features_scaled)

scaler = MinMaxScaler()
# keep our unscaled features just in case we need to process them alternatively
features_minmax = features
features_minmax = scaler.fit_transform(features_minmax)

# %% [markdown]
# Make sure our features are properly scaled:

# %%
print('\033[1m'+'Standard Scaling:\n'+'\033[0m')
features_scaled_df = pd.DataFrame(features_scaled)
print_features(features_scaled_df)

print('\n\n\033[1m'+'MinMax Scaling:\n'+'\033[0m')
features_minmax_df = pd.DataFrame(features_minmax)
print_features(features_minmax_df)
# Out:
# Standard Scaling:
#
# 12 Chromagram features:           min = -4.371,     max = 2.497,     mean = 0.000,     deviation = 1.000
#
# 128 Mel Spectrogram features:     min = -0.377,     max = 33.107,     mean = 0.000,     deviation = 1.000
#
# 40 MFCC features:                 min = -4.626,    max = 6.841,    mean = -0.000,    deviation = 1.000
#
#
# MinMax Scaling:
#
# 12 Chromagram features:           min = 0.000,     max = 1.000,     mean = 0.619,     deviation = 0.176
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 1.000,     mean = 0.016,     deviation = 0.061
#
# 40 MFCC features:                 min = 0.000,    max = 1.000,    mean = 0.384,    deviation = 0.170

# %% [markdown]
# Perfect. Zero mean and unit variance for standard scaling and in the range [0,1] for MinMax scaling - a default when we don't specify values. We can now move on to building predictive models for these features.

# %% [markdown]
# ## Classical Machine Learning Models
#
#
# Classical machine learning models encompass a broad range of algorithms that have been foundational to the field's development and are still widely used for various predictive tasks. These models can be broadly categorized into supervised and unsupervised learning methods, each suited for different kinds of data and objectives.
#
# We will be looking into few popular Machine Learning Algorithms such as Support Vector Machine(SVM), K-Nearest Neighbors and Random Forest Classifier. There are many other classical models with their own strengths and weaknesses, and the choice of model depends on the specific requirements of the task, including the nature of the data, the complexity of the problem, and the computational efficiency required. Despite the rise of deep learning, classical machine learning models remain vital tools in a data scientist's arsenal due to their efficiency, interpretability, and strong performance in many scenarios.
#
# The use of classic machine learning method is due to the small size of our dataset; Some of the most robust models such as Support vector (machine) classifiers **(SVC) and k-Nearest-Neighbour classifiers (kNN) are particularly suited to smaller datasets and fall apart with huge datasets.**

# %% [markdown]
# ### Training: The 80/20 Split and Validation
# In order to compare models, we'll have to evaluate their performance. The simplest method to do so is to train a model on a portion of our dataset and test it on the remainder. We'll use sklearn's train_test_split to create a standard 80/20 train/test split. The model is fit on 80% of
# the data and tested for performance against 20% of the data, which it has never seen in training - also called the hold-out set.
#  <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/Capture2.PNG?raw=true" width="800">
#
# More accurately, the proper modality for training and scoring a model is to
# 1. Fit/train our model on a _training_ set,
# 2. Evaluate the model on a _validation_ set to tune the hyperparameters for better performance,
# 3. Finally score our model's true performance - its **generalizability** - against a _test_ set, aka the hold-out set.
# 4. Repeat from 2. **Do not tune the model to score well on the test set**.
#
# Different set ratios are used in this approach - a usual example is 60/20/20 train/validation/test.For simplicity, we're going to start with an 80/20 train/test split. The model will be trained on all the training data, and we will check its performance on the test data.
#
#  <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/traintestsplit.PNG?raw=true" width="800">
#
# Define unscaled and scaled training and test sets:

# %%
from sklearn.model_selection import train_test_split


############# Unscaled test/train set #############
X_train, X_test, y_train, y_test =train_test_split(
    features,
    emotions,
    test_size=0.2,
    random_state=69
)

############ Standard Scaled test/train set ###########
# The labels/classes (y_train, y_test) never change, keep old values
X_train_scaled, X_test_scaled, _, _ = train_test_split(
    features_scaled,
    emotions,
    test_size=0.2,
    random_state=69
)

############# MinMax Scaled test/train set ###############
# The labels/classes (y_train, y_test) never change, keep old values
X_train_minmax, X_test_minmax, _, _ = train_test_split(
    features_minmax,
    emotions,
    test_size=0.2,
    random_state=69
)

# %% [markdown]
# ### Comparing Models
# We'll try each off-the-shelf machine learning model from sklearn and pick a few to explore, since these models will train near instantly on this dataset.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

classification_models = [
    KNeighborsClassifier(),#(3),
    SVC(kernel='linear'),#, C=0.025),
    SVC(kernel='rbf'),
    DecisionTreeClassifier(),#max_depth=5),
    RandomForestClassifier(),#max_depth=5, n_estimators=10, max_features=1),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

scores = []
for model in classification_models:
    model.fit(X_train_scaled, y_train)
    score = model.score(X_test_scaled, y_test)
    model_name = type(model).__name__
    if model_name=='SVC' and model.kernel=='rbf': model_name+=' RBF kernel'
    scores.append((model_name,(f'{100*score:.2f}%')))
# Make it pretty
scores_df = pd.DataFrame(scores,columns=['Classifier','Accuracy Score'])
scores_df.sort_values(by='Accuracy Score',axis=0,ascending=False)
# Out:
#                       Classifier Accuracy Score
# 4         RandomForestClassifier         54.84%
# 0           KNeighborsClassifier         51.03%
# 1                            SVC         50.15%
# 2                 SVC RBF kernel         43.40%
# 3         DecisionTreeClassifier         35.19%
# 5             AdaBoostClassifier         29.03%
# 6                     GaussianNB         28.15%
# 7  QuadraticDiscriminantAnalysis         19.65%

# %% [markdown]
# Let's pick the top three - Random Forests, SVC, and kNN - and take a closer look at each of them.

# %% [markdown]
# ### The Support Vector Machine Classifier
#
# We'll go in chronological order. First is the support vector machine classifier (SVC) - a model from the 60s. SVMs are models quick to train for this task and best suited to small datasets due to its quadratic time complexity w.r.t. size of the training dataset (# of training samples). This is also the reason it breaks down with larger datasets since it becomes very expensive to train.
#
# The idea behind SVMs on which the SVC model is based is to find a separating hyperplane - a subspace with dimension one less than that of the feature space - for points in our feature space; i.e. for a 3D space, a hyperplane is a regular plane, in 2D, a line. This idea extends to n dimensions. If points are separable by a hyperplane, they are said to be linearly separable. **Since there are infinite possible separating hyperplanes for any linearly separable feature space, an SVM computes which points are closest to each such hyperplane and uses them to construct a _support vector_. The SVM picks the hyperplane which maximizes the distance - _margin_ - to each support vector.** In this way, we maximize the separating ability of the chosen hyperplane.
#
# The core of SVMs is the kernel. We could map all new points from our input space, where they were not separable by a hyperplane, to a higher dimension in which we have found a hyperplane to separate the points in that space. However, that would be extremely computationally expensive for data that needs to be mapped to much higher dimensions. Instead, we **compute the hyperplane in the higher dimension on our training data and map the hyperplane back to the lower-dimension input space to use for classifying our data. This is the _kernel trick_, whereby the kernel (function) enables us to compute distances to new points in the input space without transforming each to the higher dimensional space - drastically reducing the computational complexity of the SVM.**
#
#  <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/kernel1.png?raw=true" width="800">

# %% [markdown]
# A linear kernel should always be tested because **a linear kernel is much faster to train than a non-linear kernel**; however, properly tuned, a non-linear kernel often provides the best possible predictive performance. **RBF (radial basis function) is a good default to use for a non-linear kernel** and often is the best non-linear kernel because it usually provides a higher accuracy compared to other non-linear kernels at the cost of higher computational complexity. We can afford to try the RBF kernel because our dataset is small.
#
# If you want to explore further please have a look at [this article](https://www.analyticsvidhya.com/blog/2021/10/support-vector-machinessvm-a-complete-guide-for-beginners/)

# %%
from sklearn.svm import SVC

model = SVC(
    C=10,  #higher the value tighter the margin
    gamma='auto',
    kernel='rbf',
    random_state=69
)

model.fit(X_train, y_train)

print(f'SVC Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'SVC Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# SVC Model's accuracy on training set is 100.00%
# SVC Model's accuracy on test set is 45.75%

# %% [markdown]
# Not bad at all for the relatively simple SVC model. **Hyperparameter 𝐶 regulates the margin.** It might do well to optimize the SVC model further if we don't find a better one. As it stands, we are looking for considerably higher performance in this task.
#
# Check out [this link](https://towardsdatascience.com/visualizing-the-effect-of-hyperparameters-on-support-vector-machines-b9eef6f7357b) for visual representation of affect of changes in C and gamma.

# %% [markdown]
# ### k Nearest Neighbours
#
# k Nearest Neighbours (kNN) is next in line, a tried-and-true machine learning method from the 70s. kNN makes a lot of intuitive sense: imagine plotting points on a graph and drawing gates around points that look like they belong to the same group. That's what it is - we **plot our training samples' features and compare a test sample's features' distance to all those points; then just take the _k_ closest points to the test sample and pick the most frequent label/class.** That's it.
#
# kNN is a great starting point for multiclass problems with small datasets, although on large dadtasets less reliable and extremely memory hungry (it stores all training sample points). kNN is also useful in that it makes **no assumptions about the underlying distribution of the data set - so kNNs work well for both linear and non-linear data.** In the 2D example:
#
# <img src="https://github.com/IAT-ExploringAI-2024/Week3-Machine_Learning/blob/main/images/knn.png?raw=true" width=400 height=400 />

# %%
from sklearn.neighbors import KNeighborsClassifier

####### Default kNN  ########
model = KNeighborsClassifier(
)

model.fit(X_train, y_train)

print(f'Default kNN Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Default kNN Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%\n')

##### (hastily) tuned kNN ######
model = KNeighborsClassifier(
    n_neighbors = 5,
    weights = 'distance',
    algorithm = 'brute',
    n_jobs=4
)

model.fit(X_train, y_train)

print(f'kNN Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'kNN Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# Default kNN Model's accuracy on training set is 67.79%
# Default kNN Model's accuracy on test set is 43.70%
#
# kNN Model's accuracy on training set is 100.00%
# kNN Model's accuracy on test set is 47.51%

# %% [markdown]
# **The brute-force algorithm computes distances between all pairs of points in the training set; works especially well for small datasets** but wildly inefficient w.r.t. increasing samples and feature space dimension. Not bad for 2 minutes of work, but still not suitable for this task.

# %% [markdown]
# ### Random Forests
# Finally, and before resorting to deep learning methods, let's try a Random Forest -  a model from the 21st century (2001). **We train many distinct decision trees which are essentially directed acyclic graphs (DAGs), somewhat similar to a flow chart. The collection of (decision) trees makes up our Random Forest.**
#
# At each node of the tree we have a function (a rule) that evaluates whether the features of samples input to that node belong to one class or another. Each branch of the tree (or, edge of the graph) defines one of two possible results from a node, and each leaf is one of two decisions made by its parent node. **Each tree in the forest evaluates a random subset of the training samples' features and has a rule at each level of the tree that classifies based on these random features - hence, _Random_ Forest. This random selection of features makes Random Forests robust to outliers**, as such features will have less of an impact in the scope of the entire forest, most of whose trees operate on the "real" features.
#
# **Random Forests are excellent models to use as a benchmark due to their low time complexity to train and because it is an ensemble method, their robustness to unknown distributions and outliers in the dataset,** meaning Random Forests require relatively little exploratory analysis in both the data and training the model to get an idea of their performance in a task.
#
# <img src="https://github.com/IliaZenkov/sklearn-audio-classification/blob/master/img/randomforest.png?raw=true" width=500 height=500 />

# %%
from sklearn.ensemble import RandomForestClassifier

####### Default Random Forest ########
model = RandomForestClassifier(
    random_state=69
)

model.fit(X_train, y_train)

print(f'Default Random Forest Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Default Random Forest Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%\n')


########## Tuned Random Forest #######
model = RandomForestClassifier(
    n_estimators = 500,
    criterion ='entropy',
    warm_start = True,
    max_features = 'sqrt',
    oob_score = True, # more on this below
    random_state=69
)

model.fit(X_train, y_train)

print(f'Random Forest Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Random Forest Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# Default Random Forest Model's accuracy on training set is 100.00%
# Default Random Forest Model's accuracy on test set is 53.08%
#
# Random Forest Model's accuracy on training set is 100.00%
# Random Forest Model's accuracy on test set is 55.43%

# %% [markdown]
# Not bad for zero effort put into the default model. **Random Forests make a good benchmark model**, especially when strapped for time.
#
# **_Max features_ defines size of random feature subset decided upon at each node; sqrt(#features) is a good default for classification.**
#
# **_Gini_ and _Entropy_ are functions computing quality of classified samples within each node; they almost always provide similar performance but Entropy is more suited to classification while Gini is better for continuous variables.**

# %% [markdown]
# As wonderful as Random Forests are, it's clear that we're going to need to pull out bigger guns if we want to get appreciable performance on this dataset, perhaps even with good generalizability on test data. DNNs(Deep Neural Networks) are the next step-up in complexity from classical machine learning models, and we will start at the first rung on that ladder:Simple Perceptron in next lab!
